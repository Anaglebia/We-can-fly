# %% [markdown]
# Instalando a biblioteca do *BigQuery*

# %%
# !pip install -q google-cloud-bigquery

# %%
from google.cloud import bigquery

# %%
# Instala a biblioteca google-cloud-aiplatform, se ainda não estiver instalada
# !pip install -q google-cloud-aiplatform

from google.cloud import aiplatform

# Define a localização global para o cliente da Vertex AI
aiplatform.init(
    project='tcc-fly-pnad-506019',
    location='southamerica-east1' # Exemplo: São Paulo
)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.3/52.3 kB 783.2 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 9.0 MB/s eta 0:00:00

# %%
# !pip install basedosdados
import basedosdados as bd
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 16.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.0/216.0 kB 8.9 MB/s eta 0:00:00
# ...

# %%
import os
import locale

# Ensure locales are installed and generated
# !apt-get install -y locales
# !locale-gen pt_BR.UTF-8

# Set environment variables for the locale
os.environ['LANG'] = 'pt_BR.UTF-8'
os.environ['LC_ALL'] = 'pt_BR.UTF-8'

# Explicitly set the locale in Python, rather than relying on environment defaults
try:
    locale.setlocale(locale.LC_ALL, 'pt_BR.UTF-8')
    print("Locale set to pt_BR.UTF-8 successfully.")
except locale.Error as e:
    print(f"Error setting locale: {e}")
    print("This might be an environment limitation. You may need to restart the Colab runtime or consider if this locale is strictly necessary for your current task.")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# locales is already the newest version (2.35-0ubuntu3.14).
# 0 upgraded, 0 newly installed, 0 to remove and 1 not upgraded.
# Generating locales (this might take a while)...
#   pt_BR.UTF-8... done
# Generation complete.
# Error setting locale: unsupported locale setting
# This might be an environment limitation. You may need to restart the Colab runtime or consider if this locale is strictly necessary for your current task.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import auth
auth.authenticate_user()

# %%
client = bigquery.Client(project="tcc-fly-pnad-506019") # Replace 'your-gcp-project-id' with your actual Google Cloud Project ID, or remove the argument if you want it to infer the project.

# %%
query = """SELECT
  ano,
  sigla_uf,
  V2007 AS sexo,
  V2010 AS raca_cor,
  V2009 AS idade,
  VD3004 AS escolaridade,
  VD4020 AS renda,
  V1028 AS peso
  FROM `basedosdados.br_ibge_pnadc.microdados_anual`
  TABLESAMPLE SYSTEM (5 PERCENT)
  WHERE ano = 2019 AND V2009 >= 16"""

# %%
# Exemplo em Python
job_config = bigquery.QueryJobConfig()
# Força a execução na região correta do seu dataset
query_job = client.query('tcc-fly-pnad-506019', location="southamerica-east1", job_config=job_config)
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# /tmp/ipykernel_3819/770756994.py in <cell line: 0>()
#       2 job_config = bigquery.QueryJobConfig()
#       3 # Força a execução na região correta do seu dataset
# ----> 4 query_job = client.query('tcc-fly-pnad-506019', location="southamerica-east1", job_config=job_config)
#
# /usr/local/lib/python3.13/dist-packages/google/cloud/bigquery/client.py in query(self, query, job_config, job_id, job_id_prefix, location, project, retry, timeout, job_retry, api_method, timestamp_precision)
#    3638             )
#    3639         elif api_method == enums.QueryApiMethod.INSERT:
# -> 3640             return _job_helpers.query_jobs_insert(
#    3641                 self,
#    3642                 query,
#
# ...

# %%
for t in client.list_tables("basedosdados.br_ibge_pnadc"):
  print(t.table_id)
# Out:
# ano_brasil_grupo_idade
# ano_brasil_raca_cor
# ano_municipio_grupo_idade
# ano_municipio_raca_cor
# ano_regiao_grupo_idade
# ano_regiao_metropolitana_grupo_idade
# ano_regiao_metropolitana_raca_cor
# ano_regiao_raca_cor
# ano_uf_grupo_idade
# ano_uf_raca_cor
# dicionario
# educacao
# microdados
# rendimentos_outras_fontes

# %%
tables = []
for table in client.list_tables("basedosdados.br_ibge_pnadc"):
    tables.append({
        "table_id": table.table_id,
        "table_type": table.table_type
    })
df = pd.DataFrame(tables)
print("Formato da amostra:", df.shape)
df.head()
# Out:
# Formato da amostra: (14, 2)
#                     table_id table_type
# 0     ano_brasil_grupo_idade       VIEW
# 1        ano_brasil_raca_cor       VIEW
# 2  ano_municipio_grupo_idade       VIEW
# 3     ano_municipio_raca_cor       VIEW
# 4     ano_regiao_grupo_idade       VIEW

# %% [markdown]
# ### Informações e Estatísticas do `dados_raca_cor`
#
# Vamos começar explorando o DataFrame `dados_raca_cor` para entender sua estrutura, tipos de dados e algumas estatísticas descritivas.

# %%
# Exibe informações concisas sobre o DataFrame, incluindo o tipo de dado de cada coluna e a contagem de valores não nulos.
display(dados_raca_cor.info())

# %%
# Gera estatísticas descritivas das colunas numéricas do DataFrame, como contagem, média, desvio padrão, mínimo, máximo e quartis.
display(dados_raca_cor.describe())

# %%
import pandas as pd
dados_ipea = pd.read_excel('/content/ipea_retrato_2024_tab_0301.xlsx')

# %%
dados_sidra = pd.read_csv('/content/tabela9756 - Sidra - 2022.csv', sep=';', skiprows=3)

# %%
dados_sidra.tail()

# %%
dados_sidra.shape

# %%
dados_sidra = dados_sidra.iloc[:-5]

# %%
dados_sidra
